# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_regression

# %% [markdown]
# # Creating The Dataset

# %%
X, y = make_regression(n_samples=200,n_features=3,n_informative=3,noise=20,random_state=42)

# %%
print(f"X shape :{X.shape}, y shape :{y.shape}")
# Out:
# X shape :(200, 3), y shape :(200,)

# %%
# editing the dataset 
m = X.shape[0]
ones =np.ones((m,1))  
X = np.concatenate((ones, X), axis=1)

# %% [markdown]
# # Creating The model

# %%
# this function gives the expected values
def predict(X, w):
    return np.dot(X,w)

# %%
# this function finds the best thetas in one iteration 
def normal_equation( X , y):
    w = np.zeros(X.shape[1])
    theta = np.dot(np.linalg.inv(np.dot(X.T,X)),(np.dot(X.T,y)))
    return theta

# %% [markdown]
# # Result

# %%
w = normal_equation(X,y)
print(w)
# Out:
# [-0.73502087 71.2810152  20.76603986 73.28222391]

# %% [markdown]
# # Sklearn VS normal equation (which is the same btw)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
y_pred_sklearn = model.predict(X)

# %%
print(f"Sklearn weights : {model.coef_}")
# Out:
# Sklearn weights : [ 0.         71.2810152  20.76603986 73.28222391]
